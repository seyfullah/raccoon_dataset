# %%
import cv2
import pandas as pd
from PIL import Image

# %%
full_labels = pd.read_csv('data/airplane_labels.csv')

# %%
full_labels.head()
# Out:
#           filename  width  height     class  xmin  ymin  xmax  ymax
# 0  airplane001.jpg    256     256  Airplane    82    18   196   186
# 1  airplane002.jpg    256     256  Airplane    51    47   200   196
# 2  airplane003.jpg    256     256  Airplane    23    45   230   217
# 3  airplane004.jpg    256     256  Airplane    19    55   210   209
# 4  airplane005.jpg    256     256  Airplane    47    83   177   253

# %%
def draw_boxes(image_name):
    selected_value = full_labels[full_labels.filename == image_name]
    img = cv2.imread('images/{}'.format(image_name))
    for index, row in selected_value.iterrows():
        img = cv2.rectangle(img, (row['xmin'], row['ymin']), (row['xmax'], row['ymax']), (0, 255, 0), 3)
    return img

# %%
Image.fromarray(draw_boxes('airplane001.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x21AC33207B8>

# %%
Image.fromarray(draw_boxes('airplane050.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x21AC34126A0>

# %%
Image.fromarray(draw_boxes('airplane150.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x21AC3412550>

# %%
Image.fromarray(draw_boxes('airplane200.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x21AC3412898>

# %%
Image.fromarray(draw_boxes('airplane018.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x21AC3412A58>

# %%
Image.fromarray(draw_boxes('airplane040.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x21AC3412AC8>

# %%
Image.fromarray(draw_boxes('airplane002.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x21AC3412C88>

# %%
Image.fromarray(draw_boxes('airplane022.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x21AC3412D30>

# %%
Image.fromarray(draw_boxes('airplane901.jpg'))
Image.fromarray(draw_boxes('airplane902.jpg'))
Image.fromarray(draw_boxes('airplane903.jpg'))
Image.fromarray(draw_boxes('airplane904.jpg'))
Image.fromarray(draw_boxes('airplane905.jpg'))
Image.fromarray(draw_boxes('airplane906.jpg'))
Image.fromarray(draw_boxes('airplane907.jpg'))
Image.fromarray(draw_boxes('airplane908.jpg'))
Image.fromarray(draw_boxes('airplane909.jpg'))
Image.fromarray(draw_boxes('airplane910.jpg'))
Image.fromarray(draw_boxes('airplane911.jpg'))
Image.fromarray(draw_boxes('airplane912.jpg'))
